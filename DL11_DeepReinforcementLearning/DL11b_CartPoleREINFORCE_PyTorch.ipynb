# %%
import os
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical

import imageio
from IPython.display import Image, display
from google.colab import drive

print("PyTorch version: " + torch.__version__)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Koristi se uređaj: {device}")
# Out:
# PyTorch version: 2.11.0+cu128
# Koristi se uređaj: cuda

# %%
########################################################################################################################
# MONTIRANJE GOOGLE DRIVE-A
########################################################################################################################

drive.mount('/content/drive')

drive_results_folder = '/content/drive/MyDrive/CartPoleREINFORCE_PyTorch'
if not os.path.exists(drive_results_folder):
    os.makedirs(drive_results_folder)
    print(f"Napravljen direktorijum za rezultate na Drive-u: {drive_results_folder}")

# Definisanje putanja
agent_path = os.path.join(drive_results_folder, "CartPoleREINFORCE_agent.pth")
fig_path = os.path.join(drive_results_folder, "CartPoleREINFORCE_training.png")
gif_path = os.path.join(drive_results_folder, "CartPoleREINFORCE_demo.gif")
# Out:
# Mounted at /content/drive
# Napravljen direktorijum za rezultate na Drive-u: /content/drive/MyDrive/CartPoleREINFORCE_PyTorch

# %%
########################################################################################################################
# POLICY MREŽA
########################################################################################################################

class PolicyNetwork(nn.Module):
    def __init__(self, state_size, action_size):
        super(PolicyNetwork, self).__init__()

        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, action_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        # Mreža direktno izbacuje distribuciju verovatnoća za akcije
        action_probs = F.softmax(self.fc2(x), dim=-1)
        return action_probs

# %%
########################################################################################################################
# REINFORCE AGENT KLASA (sa statističkim baseline-om)
########################################################################################################################

class REINFORCEAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size

        self.gamma = 0.99
        self.learning_rate = 0.005

        self.model = PolicyNetwork(state_size, action_size).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)

        # Liste za pamćenje istorije unutar jedne epizode
        self.saved_log_probs = []
        self.rewards = []

        # Statistički baseline (pokretni prosek)
        self.baseline = None
        self.baseline_alpha = 0.1 # Faktor osvežavanja (koliko brzo zaboravljamo stare epizode)

    def act(self, state):
        state_tensor = torch.FloatTensor(state).to(device)
        action_probs = self.model(state_tensor)

        m = Categorical(action_probs)
        action = m.sample()

        # Pamtimo logaritam verovatnoće za kasniji backpropagation
        self.saved_log_probs.append(m.log_prob(action))

        return action.item()

    def learn_episode(self):
        if not self.rewards:
            return

        # 1. Računamo diskontovane nagrade (Returns) unazad
        returns = []
        R = 0
        for r in self.rewards[::-1]:
            R = r + self.gamma * R
            returns.insert(0, R)

        returns_tensor = torch.tensor(returns).to(device)

        # 2. Ažuriranje baseline-a na bazi trenutne epizode
        episode_mean_return = returns_tensor.mean().item()

        if self.baseline is None:
            self.baseline = episode_mean_return
        else:
            # Eksponencijalni pokretni prosek (Exponential Moving Average)
            self.baseline = (1 - self.baseline_alpha) * self.baseline + self.baseline_alpha * episode_mean_return

        # 3. Računanje Advantage-a (Return - Baseline)
        policy_losses = []

        for log_prob, R in zip(self.saved_log_probs, returns_tensor):
            # Koliko je ovaj potez bio bolji/gori od istorijskog proseka
            advantage = R.item() - self.baseline

            # Policy Gradient: loss = -log_prob * advantage
            policy_losses.append(-log_prob * advantage)

        # Zbir grešaka za celu epizodu
        loss = torch.stack(policy_losses).sum()

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Čišćenje lista za novu epizodu
        self.saved_log_probs.clear()
        self.rewards.clear()

# %%
########################################################################################################################
# GLAVNA PETLJA ZA OBUČAVANJE
########################################################################################################################

env = gym.make('CartPole-v1')
state_size = int(env.observation_space.shape[0])
action_size = int(env.action_space.n)

agent = REINFORCEAgent(state_size, action_size)
episodes = 500

scores = []

print("Započinjem obučavanje...")
for e in range(episodes):
    state, info = env.reset()
    state = np.reshape(state, [1, state_size])

    time_steps = 0
    done = False

    while not done:
        action = agent.act(state)

        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated

        # Kažnjavamo ga za pad
        if terminated:
            reward = -10

        agent.rewards.append(reward)

        state = np.reshape(next_state, [1, state_size])
        time_steps += 1

        if done:
            # Učimo na kraju epizode koristeći REINFORCE sa baseline-om
            agent.learn_episode()

            print(f"Epizoda: {e+1}/{episodes} | Rezultat: {time_steps} | Trenutni Baseline: {agent.baseline:.2f}")
            scores.append(time_steps)
            break

torch.save(agent.model.state_dict(), agent_path)
print(f"Težine modela su uspešno sačuvane u fajl '{agent_path}'!")

plt.plot(scores)
plt.ylabel('Preživljeni koraci (Score)')
plt.xlabel('Epizoda')
plt.title('REINFORCE (Policy Gradients) na CartPole okruženju')
plt.savefig(fig_path)
plt.show()
# Out:
# Započinjem obučavanje...
# Epizoda: 1/500 | Rezultat: 15 | Trenutni Baseline: -2.62
# Epizoda: 2/500 | Rezultat: 31 | Trenutni Baseline: -1.86
# Epizoda: 3/500 | Rezultat: 12 | Trenutni Baseline: -2.09
# Epizoda: 4/500 | Rezultat: 11 | Trenutni Baseline: -2.35
# Epizoda: 5/500 | Rezultat: 38 | Trenutni Baseline: -1.30
# Epizoda: 6/500 | Rezultat: 20 | Trenutni Baseline: -1.19
# Epizoda: 7/500 | Rezultat: 16 | Trenutni Baseline: -1.28
# Epizoda: 8/500 | Rezultat: 35 | Trenutni Baseline: -0.47
# Epizoda: 9/500 | Rezultat: 58 | Trenutni Baseline: 1.20
# Epizoda: 10/500 | Rezultat: 14 | Trenutni Baseline: 0.77
# Epizoda: 11/500 | Rezultat: 38 | Trenutni Baseline: 1.50
# Epizoda: 12/500 | Rezultat: 34 | Trenutni Baseline: 1.98
# Epizoda: 13/500 | Rezultat: 28 | Trenutni Baseline: 2.15
# Epizoda: 14/500 | Rezultat: 17 | Trenutni Baseline: 1.77
# Epizoda: 15/500 | Rezultat: 26 | Trenutni Baseline: 1.87
# Epizoda: 16/500 | Rezultat: 54 | Trenutni Baseline: 3.15
# Epizoda: 17/500 | Rezultat: 24 | Trenutni Baseline: 3.01
# Epizoda: 18/500 | Rezultat: 24 | Trenutni Baseline: 2.89
# Epizoda: 19/500 | Rezultat: 20 | Trenutni Baseline: 2.58
# Epizoda: 20/500 | Rezultat: 92 | Trenutni Baseline: 5.11
# Epizoda: 21/500 | Rezultat: 116 | Trenutni Baseline: 8.07
# Epizoda: 22/500 | Rezultat: 19 | Trenutni Baseline: 7.20
# Epizoda: 23/500 | Rezultat: 83 | Trenutni Baseline: 8.98
# Epizoda: 24/500 | Rezultat: 41 | Trenutni Baseline: 9.02
# Epizoda: 25/500 | Rezultat: 25 | Trenutni Baseline: 8.35
# Epizoda: 26/500 | Rezultat: 146 | Trenutni Baseline: 11.71
# Epizoda: 27/500 | Rezultat: 59 | Trenutni Baseline: 12.20
# Epizoda: 28/500 | Rezultat: 28 | Trenutni Baseline: 11.35
# Epizoda: 29/500 | Rezultat: 73 | Trenutni Baseline: 12.38
# Epizoda: 30/500 | Rezultat: 67 | Trenutni Baseline: 13.10
# Epizoda: 31/500 | Rezultat: 59 | Trenutni Baseline: 13.45
# Epizoda: 32/500 | Rezultat: 181 | Trenutni Baseline: 17.01
# Epizoda: 33/500 | Rezultat: 133 | Trenutni Baseline: 19.21
# Epizoda: 34/500 | Rezultat: 82 | Trenutni Baseline: 19.76
# Epizoda: 35/500 | Rezultat: 92 | Trenutni Baseline: 20.57
# Epizoda: 36/500 | Rezultat: 30 | Trenutni Baseline: 18.97
# Epizoda: 37/500 | Rezultat: 169 | Trenutni Baseline: 21.75
# Epizoda: 38/500 | Rezultat: 83 | Trenutni Baseline: 22.08
# Epizoda: 39/500 | Rezultat: 87 | Trenutni Baseline: 22.50
# Epizoda: 40/500 | Rezultat: 157 | Trenutni Baseline: 24.69
# Epizoda: 41/500 | Rezultat: 111 | Trenutni Baseline: 25.56
# Epizoda: 42/500 | Rezultat: 84 | Trenutni Baseline: 25.54
# Epizoda: 43/500 | Rezultat: 59 | Trenutni Baseline: 24.64
# Epizoda: 44/500 | Rezultat: 128 | Trenutni Baseline: 25.96
# Epizoda: 45/500 | Rezultat: 128 | Trenutni Baseline: 27.14
# Epizoda: 46/500 | Rezultat: 113 | Trenutni Baseline: 27.82
# Epizoda: 47/500 | Rezultat: 76 | Trenutni Baseline: 27.31
# Epizoda: 48/500 | Rezultat: 254 | Trenutni Baseline: 30.59
# Epizoda: 49/500 | Rezultat: 32 | Trenutni Baseline: 28.07
# Epizoda: 50/500 | Rezultat: 149 | Trenutni Baseline: 29.53
# Epizoda: 51/500 | Rezultat: 120 | Trenutni Baseline: 30.16
# Epizoda: 52/500 | Rezultat: 148 | Trenutni Baseline: 31.39
# Epizoda: 53/500 | Rezultat: 432 | Trenutni Baseline: 35.74
# Epizoda: 54/500 | Rezultat: 130 | Trenutni Baseline: 35.99
# Epizoda: 55/500 | Rezultat: 140 | Trenutni Baseline: 36.46
# Epizoda: 56/500 | Rezultat: 139 | Trenutni Baseline: 36.86
# Epizoda: 57/500 | Rezultat: 203 | Trenutni Baseline: 38.46
# Epizoda: 58/500 | Rezultat: 133 | Trenutni Baseline: 38.51
# Epizoda: 59/500 | Rezultat: 146 | Trenutni Baseline: 38.87
# Epizoda: 60/500 | Rezultat: 349 | Trenutni Baseline: 41.92
# Epizoda: 61/500 | Rezultat: 151 | Trenutni Baseline: 42.04
# Epizoda: 62/500 | Rezultat: 238 | Trenutni Baseline: 43.64
# Epizoda: 63/500 | Rezultat: 129 | Trenutni Baseline: 43.08
# Epizoda: 64/500 | Rezultat: 500 | Trenutni Baseline: 46.80
# Epizoda: 65/500 | Rezultat: 338 | Trenutni Baseline: 48.98
# Epizoda: 66/500 | Rezultat: 308 | Trenutni Baseline: 50.67
# Epizoda: 67/500 | Rezultat: 90 | Trenutni Baseline: 48.33
# Epizoda: 68/500 | Rezultat: 147 | Trenutni Baseline: 47.72
# Epizoda: 69/500 | Rezultat: 151 | Trenutni Baseline: 47.26
# Epizoda: 70/500 | Rezultat: 172 | Trenutni Baseline: 47.27
# Epizoda: 71/500 | Rezultat: 126 | Trenutni Baseline: 46.28
# Epizoda: 72/500 | Rezultat: 157 | Trenutni Baseline: 46.09
# Epizoda: 73/500 | Rezultat: 147 | Trenutni Baseline: 45.71
# Epizoda: 74/500 | Rezultat: 280 | Trenutni Baseline: 47.44
# Epizoda: 75/500 | Rezultat: 202 | Trenutni Baseline: 47.97
# Epizoda: 76/500 | Rezultat: 243 | Trenutni Baseline: 49.04
# Epizoda: 77/500 | Rezultat: 107 | Trenutni Baseline: 47.36
# Epizoda: 78/500 | Rezultat: 139 | Trenutni Baseline: 46.67
# Epizoda: 79/500 | Rezultat: 292 | Trenutni Baseline: 48.43
# Epizoda: 80/500 | Rezultat: 489 | Trenutni Baseline: 51.36
# Epizoda: 81/500 | Rezultat: 106 | Trenutni Baseline: 49.42
# Epizoda: 82/500 | Rezultat: 500 | Trenutni Baseline: 52.51
# Epizoda: 83/500 | Rezultat: 335 | Trenutni Baseline: 54.09
# Epizoda: 84/500 | Rezultat: 103 | Trenutni Baseline: 51.79
# Epizoda: 85/500 | Rezultat: 426 | Trenutni Baseline: 54.07
# Epizoda: 86/500 | Rezultat: 163 | Trenutni Baseline: 53.22
# Epizoda: 87/500 | Rezultat: 255 | Trenutni Baseline: 53.92
# Epizoda: 88/500 | Rezultat: 109 | Trenutni Baseline: 51.81
# Epizoda: 89/500 | Rezultat: 318 | Trenutni Baseline: 53.31
# Epizoda: 90/500 | Rezultat: 500 | Trenutni Baseline: 56.01
# Epizoda: 91/500 | Rezultat: 500 | Trenutni Baseline: 58.45
# Epizoda: 92/500 | Rezultat: 500 | Trenutni Baseline: 60.63
# Epizoda: 93/500 | Rezultat: 500 | Trenutni Baseline: 62.60
# Epizoda: 94/500 | Rezultat: 500 | Trenutni Baseline: 64.38
# Epizoda: 95/500 | Rezultat: 500 | Trenutni Baseline: 65.97
# Epizoda: 96/500 | Rezultat: 329 | Trenutni Baseline: 66.15
# Epizoda: 97/500 | Rezultat: 405 | Trenutni Baseline: 66.87
# Epizoda: 98/500 | Rezultat: 500 | Trenutni Baseline: 68.22
# Epizoda: 99/500 | Rezultat: 500 | Trenutni Baseline: 69.43
# Epizoda: 100/500 | Rezultat: 500 | Trenutni Baseline: 70.52
# Epizoda: 101/500 | Rezultat: 372 | Trenutni Baseline: 70.58
# Epizoda: 102/500 | Rezultat: 500 | Trenutni Baseline: 71.55
# Epizoda: 103/500 | Rezultat: 291 | Trenutni Baseline: 70.82
# Epizoda: 104/500 | Rezultat: 500 | Trenutni Baseline: 71.77
# Epizoda: 105/500 | Rezultat: 88 | Trenutni Baseline: 67.26
# Epizoda: 106/500 | Rezultat: 500 | Trenutni Baseline: 68.56
# Epizoda: 107/500 | Rezultat: 500 | Trenutni Baseline: 69.74
# Epizoda: 108/500 | Rezultat: 500 | Trenutni Baseline: 70.80
# Epizoda: 109/500 | Rezultat: 500 | Trenutni Baseline: 71.75
# Epizoda: 110/500 | Rezultat: 500 | Trenutni Baseline: 72.61
# Epizoda: 111/500 | Rezultat: 500 | Trenutni Baseline: 73.38
# Epizoda: 112/500 | Rezultat: 500 | Trenutni Baseline: 74.08
# Epizoda: 113/500 | Rezultat: 500 | Trenutni Baseline: 74.70
# Epizoda: 114/500 | Rezultat: 500 | Trenutni Baseline: 75.27
# Epizoda: 115/500 | Rezultat: 500 | Trenutni Baseline: 75.77
# Epizoda: 116/500 | Rezultat: 500 | Trenutni Baseline: 76.23
# Epizoda: 117/500 | Rezultat: 500 | Trenutni Baseline: 76.64
# Epizoda: 118/500 | Rezultat: 500 | Trenutni Baseline: 77.01
# Epizoda: 119/500 | Rezultat: 500 | Trenutni Baseline: 77.34
# Epizoda: 120/500 | Rezultat: 500 | Trenutni Baseline: 77.64
# Epizoda: 121/500 | Rezultat: 500 | Trenutni Baseline: 77.91
# Epizoda: 122/500 | Rezultat: 500 | Trenutni Baseline: 78.15
# Epizoda: 123/500 | Rezultat: 500 | Trenutni Baseline: 78.37
# Epizoda: 124/500 | Rezultat: 500 | Trenutni Baseline: 78.56
# Epizoda: 125/500 | Rezultat: 500 | Trenutni Baseline: 78.74
# Epizoda: 126/500 | Rezultat: 500 | Trenutni Baseline: 78.90
# Epizoda: 127/500 | Rezultat: 500 | Trenutni Baseline: 79.04
# Epizoda: 128/500 | Rezultat: 500 | Trenutni Baseline: 79.17
# Epizoda: 129/500 | Rezultat: 500 | Trenutni Baseline: 79.29
# Epizoda: 130/500 | Rezultat: 500 | Trenutni Baseline: 79.39
# Epizoda: 131/500 | Rezultat: 500 | Trenutni Baseline: 79.49
# Epizoda: 132/500 | Rezultat: 500 | Trenutni Baseline: 79.57
# Epizoda: 133/500 | Rezultat: 500 | Trenutni Baseline: 79.65
# Epizoda: 134/500 | Rezultat: 500 | Trenutni Baseline: 79.71
# Epizoda: 135/500 | Rezultat: 500 | Trenutni Baseline: 79.78
# Epizoda: 136/500 | Rezultat: 500 | Trenutni Baseline: 79.83
# Epizoda: 137/500 | Rezultat: 500 | Trenutni Baseline: 79.88
# Epizoda: 138/500 | Rezultat: 500 | Trenutni Baseline: 79.93
# Epizoda: 139/500 | Rezultat: 500 | Trenutni Baseline: 79.97
# Epizoda: 140/500 | Rezultat: 500 | Trenutni Baseline: 80.00
# Epizoda: 141/500 | Rezultat: 500 | Trenutni Baseline: 80.04
# Epizoda: 142/500 | Rezultat: 500 | Trenutni Baseline: 80.07
# Epizoda: 143/500 | Rezultat: 500 | Trenutni Baseline: 80.09
# Epizoda: 144/500 | Rezultat: 500 | Trenutni Baseline: 80.12
# Epizoda: 145/500 | Rezultat: 500 | Trenutni Baseline: 80.14
# Epizoda: 146/500 | Rezultat: 500 | Trenutni Baseline: 80.16
# Epizoda: 147/500 | Rezultat: 500 | Trenutni Baseline: 80.17
# Epizoda: 148/500 | Rezultat: 500 | Trenutni Baseline: 80.19
# Epizoda: 149/500 | Rezultat: 500 | Trenutni Baseline: 80.20
# Epizoda: 150/500 | Rezultat: 500 | Trenutni Baseline: 80.22
# Epizoda: 151/500 | Rezultat: 500 | Trenutni Baseline: 80.23
# Epizoda: 152/500 | Rezultat: 500 | Trenutni Baseline: 80.24
# Epizoda: 153/500 | Rezultat: 500 | Trenutni Baseline: 80.25
# Epizoda: 154/500 | Rezultat: 500 | Trenutni Baseline: 80.26
# Epizoda: 155/500 | Rezultat: 500 | Trenutni Baseline: 80.26
# Epizoda: 156/500 | Rezultat: 500 | Trenutni Baseline: 80.27
# Epizoda: 157/500 | Rezultat: 500 | Trenutni Baseline: 80.28
# Epizoda: 158/500 | Rezultat: 500 | Trenutni Baseline: 80.28
# Epizoda: 159/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 160/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 161/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 162/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 163/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 164/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 165/500 | Rezultat: 500 | Trenutni Baseline: 80.31
# Epizoda: 166/500 | Rezultat: 500 | Trenutni Baseline: 80.31
# Epizoda: 167/500 | Rezultat: 397 | Trenutni Baseline: 79.56
# Epizoda: 168/500 | Rezultat: 500 | Trenutni Baseline: 79.64
# Epizoda: 169/500 | Rezultat: 500 | Trenutni Baseline: 79.71
# Epizoda: 170/500 | Rezultat: 500 | Trenutni Baseline: 79.77
# Epizoda: 171/500 | Rezultat: 500 | Trenutni Baseline: 79.82
# Epizoda: 172/500 | Rezultat: 500 | Trenutni Baseline: 79.87
# Epizoda: 173/500 | Rezultat: 500 | Trenutni Baseline: 79.92
# Epizoda: 174/500 | Rezultat: 500 | Trenutni Baseline: 79.96
# Epizoda: 175/500 | Rezultat: 237 | Trenutni Baseline: 77.75
# Epizoda: 176/500 | Rezultat: 500 | Trenutni Baseline: 78.01
# Epizoda: 177/500 | Rezultat: 500 | Trenutni Baseline: 78.24
# Epizoda: 178/500 | Rezultat: 500 | Trenutni Baseline: 78.45
# Epizoda: 179/500 | Rezultat: 500 | Trenutni Baseline: 78.64
# Epizoda: 180/500 | Rezultat: 500 | Trenutni Baseline: 78.81
# Epizoda: 181/500 | Rezultat: 500 | Trenutni Baseline: 78.96
# Epizoda: 182/500 | Rezultat: 500 | Trenutni Baseline: 79.10
# Epizoda: 183/500 | Rezultat: 500 | Trenutni Baseline: 79.22
# Epizoda: 184/500 | Rezultat: 500 | Trenutni Baseline: 79.33
# Epizoda: 185/500 | Rezultat: 500 | Trenutni Baseline: 79.43
# Epizoda: 186/500 | Rezultat: 500 | Trenutni Baseline: 79.52
# Epizoda: 187/500 | Rezultat: 500 | Trenutni Baseline: 79.60
# Epizoda: 188/500 | Rezultat: 500 | Trenutni Baseline: 79.67
# Epizoda: 189/500 | Rezultat: 500 | Trenutni Baseline: 79.74
# Epizoda: 190/500 | Rezultat: 500 | Trenutni Baseline: 79.80
# Epizoda: 191/500 | Rezultat: 500 | Trenutni Baseline: 79.85
# Epizoda: 192/500 | Rezultat: 500 | Trenutni Baseline: 79.90
# Epizoda: 193/500 | Rezultat: 500 | Trenutni Baseline: 79.94
# Epizoda: 194/500 | Rezultat: 500 | Trenutni Baseline: 79.98
# Epizoda: 195/500 | Rezultat: 361 | Trenutni Baseline: 79.02
# Epizoda: 196/500 | Rezultat: 321 | Trenutni Baseline: 77.83
# Epizoda: 197/500 | Rezultat: 245 | Trenutni Baseline: 75.94
# Epizoda: 198/500 | Rezultat: 275 | Trenutni Baseline: 74.59
# Epizoda: 199/500 | Rezultat: 356 | Trenutni Baseline: 74.13
# Epizoda: 200/500 | Rezultat: 356 | Trenutni Baseline: 73.71
# Epizoda: 201/500 | Rezultat: 454 | Trenutni Baseline: 73.95
# Epizoda: 202/500 | Rezultat: 500 | Trenutni Baseline: 74.58
# Epizoda: 203/500 | Rezultat: 500 | Trenutni Baseline: 75.16
# Epizoda: 204/500 | Rezultat: 500 | Trenutni Baseline: 75.68
# Epizoda: 205/500 | Rezultat: 500 | Trenutni Baseline: 76.14
# Epizoda: 206/500 | Rezultat: 500 | Trenutni Baseline: 76.56
# Epizoda: 207/500 | Rezultat: 500 | Trenutni Baseline: 76.94
# Epizoda: 208/500 | Rezultat: 500 | Trenutni Baseline: 77.28
# Epizoda: 209/500 | Rezultat: 500 | Trenutni Baseline: 77.58
# Epizoda: 210/500 | Rezultat: 500 | Trenutni Baseline: 77.86
# Epizoda: 211/500 | Rezultat: 500 | Trenutni Baseline: 78.10
# Epizoda: 212/500 | Rezultat: 500 | Trenutni Baseline: 78.33
# Epizoda: 213/500 | Rezultat: 500 | Trenutni Baseline: 78.53
# Epizoda: 214/500 | Rezultat: 500 | Trenutni Baseline: 78.71
# Epizoda: 215/500 | Rezultat: 500 | Trenutni Baseline: 78.87
# Epizoda: 216/500 | Rezultat: 500 | Trenutni Baseline: 79.02
# Epizoda: 217/500 | Rezultat: 500 | Trenutni Baseline: 79.15
# Epizoda: 218/500 | Rezultat: 500 | Trenutni Baseline: 79.27
# Epizoda: 219/500 | Rezultat: 392 | Trenutni Baseline: 78.59
# Epizoda: 220/500 | Rezultat: 362 | Trenutni Baseline: 77.77
# Epizoda: 221/500 | Rezultat: 500 | Trenutni Baseline: 78.03
# Epizoda: 222/500 | Rezultat: 336 | Trenutni Baseline: 77.06
# Epizoda: 223/500 | Rezultat: 500 | Trenutni Baseline: 77.39
# Epizoda: 224/500 | Rezultat: 500 | Trenutni Baseline: 77.68
# Epizoda: 225/500 | Rezultat: 390 | Trenutni Baseline: 77.15
# Epizoda: 226/500 | Rezultat: 350 | Trenutni Baseline: 76.38
# Epizoda: 227/500 | Rezultat: 500 | Trenutni Baseline: 76.78
# Epizoda: 228/500 | Rezultat: 500 | Trenutni Baseline: 77.13
# Epizoda: 229/500 | Rezultat: 500 | Trenutni Baseline: 77.45
# Epizoda: 230/500 | Rezultat: 500 | Trenutni Baseline: 77.74
# Epizoda: 231/500 | Rezultat: 450 | Trenutni Baseline: 77.55
# Epizoda: 232/500 | Rezultat: 500 | Trenutni Baseline: 77.83
# Epizoda: 233/500 | Rezultat: 500 | Trenutni Baseline: 78.08
# Epizoda: 234/500 | Rezultat: 500 | Trenutni Baseline: 78.30
# Epizoda: 235/500 | Rezultat: 500 | Trenutni Baseline: 78.51
# Epizoda: 236/500 | Rezultat: 500 | Trenutni Baseline: 78.69
# Epizoda: 237/500 | Rezultat: 500 | Trenutni Baseline: 78.85
# Epizoda: 238/500 | Rezultat: 109 | Trenutni Baseline: 74.25
# Epizoda: 239/500 | Rezultat: 500 | Trenutni Baseline: 74.86
# Epizoda: 240/500 | Rezultat: 500 | Trenutni Baseline: 75.41
# Epizoda: 241/500 | Rezultat: 500 | Trenutni Baseline: 75.90
# Epizoda: 242/500 | Rezultat: 500 | Trenutni Baseline: 76.34
# Epizoda: 243/500 | Rezultat: 500 | Trenutni Baseline: 76.74
# Epizoda: 244/500 | Rezultat: 500 | Trenutni Baseline: 77.10
# Epizoda: 245/500 | Rezultat: 500 | Trenutni Baseline: 77.42
# Epizoda: 246/500 | Rezultat: 500 | Trenutni Baseline: 77.71
# Epizoda: 247/500 | Rezultat: 500 | Trenutni Baseline: 77.97
# Epizoda: 248/500 | Rezultat: 500 | Trenutni Baseline: 78.21
# Epizoda: 249/500 | Rezultat: 500 | Trenutni Baseline: 78.42
# Epizoda: 250/500 | Rezultat: 500 | Trenutni Baseline: 78.61
# Epizoda: 251/500 | Rezultat: 500 | Trenutni Baseline: 78.78
# Epizoda: 252/500 | Rezultat: 500 | Trenutni Baseline: 78.94
# Epizoda: 253/500 | Rezultat: 500 | Trenutni Baseline: 79.08
# Epizoda: 254/500 | Rezultat: 500 | Trenutni Baseline: 79.20
# Epizoda: 255/500 | Rezultat: 500 | Trenutni Baseline: 79.32
# Epizoda: 256/500 | Rezultat: 500 | Trenutni Baseline: 79.42
# Epizoda: 257/500 | Rezultat: 500 | Trenutni Baseline: 79.51
# Epizoda: 258/500 | Rezultat: 500 | Trenutni Baseline: 79.59
# Epizoda: 259/500 | Rezultat: 500 | Trenutni Baseline: 79.66
# Epizoda: 260/500 | Rezultat: 500 | Trenutni Baseline: 79.73
# Epizoda: 261/500 | Rezultat: 500 | Trenutni Baseline: 79.79
# Epizoda: 262/500 | Rezultat: 500 | Trenutni Baseline: 79.85
# Epizoda: 263/500 | Rezultat: 500 | Trenutni Baseline: 79.89
# Epizoda: 264/500 | Rezultat: 500 | Trenutni Baseline: 79.94
# Epizoda: 265/500 | Rezultat: 500 | Trenutni Baseline: 79.98
# Epizoda: 266/500 | Rezultat: 500 | Trenutni Baseline: 80.01
# Epizoda: 267/500 | Rezultat: 500 | Trenutni Baseline: 80.04
# Epizoda: 268/500 | Rezultat: 500 | Trenutni Baseline: 80.07
# Epizoda: 269/500 | Rezultat: 500 | Trenutni Baseline: 80.10
# Epizoda: 270/500 | Rezultat: 500 | Trenutni Baseline: 80.12
# Epizoda: 271/500 | Rezultat: 500 | Trenutni Baseline: 80.14
# Epizoda: 272/500 | Rezultat: 500 | Trenutni Baseline: 80.16
# Epizoda: 273/500 | Rezultat: 500 | Trenutni Baseline: 80.18
# Epizoda: 274/500 | Rezultat: 500 | Trenutni Baseline: 80.19
# Epizoda: 275/500 | Rezultat: 500 | Trenutni Baseline: 80.21
# Epizoda: 276/500 | Rezultat: 500 | Trenutni Baseline: 80.22
# Epizoda: 277/500 | Rezultat: 500 | Trenutni Baseline: 80.23
# Epizoda: 278/500 | Rezultat: 500 | Trenutni Baseline: 80.24
# Epizoda: 279/500 | Rezultat: 500 | Trenutni Baseline: 80.25
# Epizoda: 280/500 | Rezultat: 500 | Trenutni Baseline: 80.26
# Epizoda: 281/500 | Rezultat: 500 | Trenutni Baseline: 80.26
# Epizoda: 282/500 | Rezultat: 500 | Trenutni Baseline: 80.27
# Epizoda: 283/500 | Rezultat: 500 | Trenutni Baseline: 80.28
# Epizoda: 284/500 | Rezultat: 500 | Trenutni Baseline: 80.28
# Epizoda: 285/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 286/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 287/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 288/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 289/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 290/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 291/500 | Rezultat: 500 | Trenutni Baseline: 80.31
# Epizoda: 292/500 | Rezultat: 500 | Trenutni Baseline: 80.31
# Epizoda: 293/500 | Rezultat: 500 | Trenutni Baseline: 80.31
# Epizoda: 294/500 | Rezultat: 500 | Trenutni Baseline: 80.31
# Epizoda: 295/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 296/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 297/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 298/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 299/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 300/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 301/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 302/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 303/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 304/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 305/500 | Rezultat: 500 | Trenutni Baseline: 80.32
# Epizoda: 306/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 307/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 308/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 309/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 310/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 311/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 312/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 313/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 314/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 315/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 316/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 317/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 318/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 319/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 320/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 321/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 322/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 323/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 324/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 325/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 326/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 327/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 328/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 329/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 330/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 331/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 332/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 333/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 334/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 335/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 336/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 337/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 338/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 339/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 340/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 341/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 342/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 343/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 344/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 345/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 346/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 347/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 348/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 349/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 350/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 351/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 352/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 353/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 354/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 355/500 | Rezultat: 500 | Trenutni Baseline: 80.33
# Epizoda: 356/500 | Rezultat: 93 | Trenutni Baseline: 75.11
# Epizoda: 357/500 | Rezultat: 500 | Trenutni Baseline: 75.64
# Epizoda: 358/500 | Rezultat: 500 | Trenutni Baseline: 76.11
# Epizoda: 359/500 | Rezultat: 500 | Trenutni Baseline: 76.53
# Epizoda: 360/500 | Rezultat: 500 | Trenutni Baseline: 76.91
# Epizoda: 361/500 | Rezultat: 500 | Trenutni Baseline: 77.25
# Epizoda: 362/500 | Rezultat: 500 | Trenutni Baseline: 77.56
# Epizoda: 363/500 | Rezultat: 500 | Trenutni Baseline: 77.84
# Epizoda: 364/500 | Rezultat: 500 | Trenutni Baseline: 78.08
# Epizoda: 365/500 | Rezultat: 500 | Trenutni Baseline: 78.31
# Epizoda: 366/500 | Rezultat: 500 | Trenutni Baseline: 78.51
# Epizoda: 367/500 | Rezultat: 500 | Trenutni Baseline: 78.69
# Epizoda: 368/500 | Rezultat: 500 | Trenutni Baseline: 78.86
# Epizoda: 369/500 | Rezultat: 500 | Trenutni Baseline: 79.00
# Epizoda: 370/500 | Rezultat: 500 | Trenutni Baseline: 79.14
# Epizoda: 371/500 | Rezultat: 500 | Trenutni Baseline: 79.26
# Epizoda: 372/500 | Rezultat: 500 | Trenutni Baseline: 79.36
# Epizoda: 373/500 | Rezultat: 500 | Trenutni Baseline: 79.46
# Epizoda: 374/500 | Rezultat: 500 | Trenutni Baseline: 79.55
# Epizoda: 375/500 | Rezultat: 500 | Trenutni Baseline: 79.63
# Epizoda: 376/500 | Rezultat: 500 | Trenutni Baseline: 79.70
# Epizoda: 377/500 | Rezultat: 500 | Trenutni Baseline: 79.76
# Epizoda: 378/500 | Rezultat: 500 | Trenutni Baseline: 79.82
# Epizoda: 379/500 | Rezultat: 500 | Trenutni Baseline: 79.87
# Epizoda: 380/500 | Rezultat: 286 | Trenutni Baseline: 78.25
# Epizoda: 381/500 | Rezultat: 446 | Trenutni Baseline: 77.99
# Epizoda: 382/500 | Rezultat: 500 | Trenutni Baseline: 78.22
# Epizoda: 383/500 | Rezultat: 500 | Trenutni Baseline: 78.43
# Epizoda: 384/500 | Rezultat: 500 | Trenutni Baseline: 78.62
# Epizoda: 385/500 | Rezultat: 500 | Trenutni Baseline: 78.79
# Epizoda: 386/500 | Rezultat: 370 | Trenutni Baseline: 78.01
# Epizoda: 387/500 | Rezultat: 500 | Trenutni Baseline: 78.25
# Epizoda: 388/500 | Rezultat: 500 | Trenutni Baseline: 78.45
# Epizoda: 389/500 | Rezultat: 500 | Trenutni Baseline: 78.64
# Epizoda: 390/500 | Rezultat: 500 | Trenutni Baseline: 78.81
# Epizoda: 391/500 | Rezultat: 500 | Trenutni Baseline: 78.96
# Epizoda: 392/500 | Rezultat: 500 | Trenutni Baseline: 79.10
# Epizoda: 393/500 | Rezultat: 500 | Trenutni Baseline: 79.22
# Epizoda: 394/500 | Rezultat: 500 | Trenutni Baseline: 79.33
# Epizoda: 395/500 | Rezultat: 500 | Trenutni Baseline: 79.43
# Epizoda: 396/500 | Rezultat: 500 | Trenutni Baseline: 79.52
# Epizoda: 397/500 | Rezultat: 500 | Trenutni Baseline: 79.60
# Epizoda: 398/500 | Rezultat: 500 | Trenutni Baseline: 79.68
# Epizoda: 399/500 | Rezultat: 500 | Trenutni Baseline: 79.74
# Epizoda: 400/500 | Rezultat: 96 | Trenutni Baseline: 74.67
# Epizoda: 401/500 | Rezultat: 500 | Trenutni Baseline: 75.24
# Epizoda: 402/500 | Rezultat: 500 | Trenutni Baseline: 75.75
# Epizoda: 403/500 | Rezultat: 500 | Trenutni Baseline: 76.21
# Epizoda: 404/500 | Rezultat: 500 | Trenutni Baseline: 76.62
# Epizoda: 405/500 | Rezultat: 500 | Trenutni Baseline: 76.99
# Epizoda: 406/500 | Rezultat: 500 | Trenutni Baseline: 77.32
# Epizoda: 407/500 | Rezultat: 500 | Trenutni Baseline: 77.63
# Epizoda: 408/500 | Rezultat: 500 | Trenutni Baseline: 77.90
# Epizoda: 409/500 | Rezultat: 500 | Trenutni Baseline: 78.14
# Epizoda: 410/500 | Rezultat: 500 | Trenutni Baseline: 78.36
# Epizoda: 411/500 | Rezultat: 500 | Trenutni Baseline: 78.56
# Epizoda: 412/500 | Rezultat: 500 | Trenutni Baseline: 78.73
# Epizoda: 413/500 | Rezultat: 500 | Trenutni Baseline: 78.89
# Epizoda: 414/500 | Rezultat: 500 | Trenutni Baseline: 79.04
# Epizoda: 415/500 | Rezultat: 500 | Trenutni Baseline: 79.17
# Epizoda: 416/500 | Rezultat: 500 | Trenutni Baseline: 79.28
# Epizoda: 417/500 | Rezultat: 500 | Trenutni Baseline: 79.39
# Epizoda: 418/500 | Rezultat: 500 | Trenutni Baseline: 79.48
# Epizoda: 419/500 | Rezultat: 500 | Trenutni Baseline: 79.57
# Epizoda: 420/500 | Rezultat: 500 | Trenutni Baseline: 79.64
# Epizoda: 421/500 | Rezultat: 500 | Trenutni Baseline: 79.71
# Epizoda: 422/500 | Rezultat: 500 | Trenutni Baseline: 79.77
# Epizoda: 423/500 | Rezultat: 500 | Trenutni Baseline: 79.83
# Epizoda: 424/500 | Rezultat: 500 | Trenutni Baseline: 79.88
# Epizoda: 425/500 | Rezultat: 500 | Trenutni Baseline: 79.92
# Epizoda: 426/500 | Rezultat: 500 | Trenutni Baseline: 79.96
# Epizoda: 427/500 | Rezultat: 500 | Trenutni Baseline: 80.00
# Epizoda: 428/500 | Rezultat: 500 | Trenutni Baseline: 80.03
# Epizoda: 429/500 | Rezultat: 500 | Trenutni Baseline: 80.06
# Epizoda: 430/500 | Rezultat: 500 | Trenutni Baseline: 80.09
# Epizoda: 431/500 | Rezultat: 500 | Trenutni Baseline: 80.11
# Epizoda: 432/500 | Rezultat: 500 | Trenutni Baseline: 80.14
# Epizoda: 433/500 | Rezultat: 500 | Trenutni Baseline: 80.16
# Epizoda: 434/500 | Rezultat: 500 | Trenutni Baseline: 80.17
# Epizoda: 435/500 | Rezultat: 500 | Trenutni Baseline: 80.19
# Epizoda: 436/500 | Rezultat: 500 | Trenutni Baseline: 80.20
# Epizoda: 437/500 | Rezultat: 500 | Trenutni Baseline: 80.22
# Epizoda: 438/500 | Rezultat: 500 | Trenutni Baseline: 80.23
# Epizoda: 439/500 | Rezultat: 500 | Trenutni Baseline: 80.24
# Epizoda: 440/500 | Rezultat: 500 | Trenutni Baseline: 80.25
# Epizoda: 441/500 | Rezultat: 500 | Trenutni Baseline: 80.25
# Epizoda: 442/500 | Rezultat: 500 | Trenutni Baseline: 80.26
# Epizoda: 443/500 | Rezultat: 500 | Trenutni Baseline: 80.27
# Epizoda: 444/500 | Rezultat: 500 | Trenutni Baseline: 80.28
# Epizoda: 445/500 | Rezultat: 500 | Trenutni Baseline: 80.28
# Epizoda: 446/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 447/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 448/500 | Rezultat: 500 | Trenutni Baseline: 80.29
# Epizoda: 449/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 450/500 | Rezultat: 500 | Trenutni Baseline: 80.30
# Epizoda: 451/500 | Rezultat: 312 | Trenutni Baseline: 78.90
# Epizoda: 452/500 | Rezultat: 500 | Trenutni Baseline: 79.04
# Epizoda: 453/500 | Rezultat: 500 | Trenutni Baseline: 79.17
# Epizoda: 454/500 | Rezultat: 500 | Trenutni Baseline: 79.29
# Epizoda: 455/500 | Rezultat: 500 | Trenutni Baseline: 79.39
# Epizoda: 456/500 | Rezultat: 500 | Trenutni Baseline: 79.48
# Epizoda: 457/500 | Rezultat: 500 | Trenutni Baseline: 79.57
# Epizoda: 458/500 | Rezultat: 500 | Trenutni Baseline: 79.65
# Epizoda: 459/500 | Rezultat: 170 | Trenutni Baseline: 76.38
# Epizoda: 460/500 | Rezultat: 500 | Trenutni Baseline: 76.78
# Epizoda: 461/500 | Rezultat: 500 | Trenutni Baseline: 77.13
# Epizoda: 462/500 | Rezultat: 500 | Trenutni Baseline: 77.45
# Epizoda: 463/500 | Rezultat: 500 | Trenutni Baseline: 77.74
# Epizoda: 464/500 | Rezultat: 500 | Trenutni Baseline: 78.00
# Epizoda: 465/500 | Rezultat: 500 | Trenutni Baseline: 78.23
# Epizoda: 466/500 | Rezultat: 500 | Trenutni Baseline: 78.44
# Epizoda: 467/500 | Rezultat: 500 | Trenutni Baseline: 78.63
# Epizoda: 468/500 | Rezultat: 500 | Trenutni Baseline: 78.80
# Epizoda: 469/500 | Rezultat: 500 | Trenutni Baseline: 78.95
# Epizoda: 470/500 | Rezultat: 500 | Trenutni Baseline: 79.09
# Epizoda: 471/500 | Rezultat: 500 | Trenutni Baseline: 79.22
# Epizoda: 472/500 | Rezultat: 500 | Trenutni Baseline: 79.33
# Epizoda: 473/500 | Rezultat: 500 | Trenutni Baseline: 79.43
# Epizoda: 474/500 | Rezultat: 500 | Trenutni Baseline: 79.52
# Epizoda: 475/500 | Rezultat: 500 | Trenutni Baseline: 79.60
# Epizoda: 476/500 | Rezultat: 500 | Trenutni Baseline: 79.67
# Epizoda: 477/500 | Rezultat: 500 | Trenutni Baseline: 79.74
# Epizoda: 478/500 | Rezultat: 500 | Trenutni Baseline: 79.80
# Epizoda: 479/500 | Rezultat: 500 | Trenutni Baseline: 79.85
# Epizoda: 480/500 | Rezultat: 500 | Trenutni Baseline: 79.90
# Epizoda: 481/500 | Rezultat: 500 | Trenutni Baseline: 79.94
# Epizoda: 482/500 | Rezultat: 500 | Trenutni Baseline: 79.98
# Epizoda: 483/500 | Rezultat: 500 | Trenutni Baseline: 80.02
# Epizoda: 484/500 | Rezultat: 500 | Trenutni Baseline: 80.05
# Epizoda: 485/500 | Rezultat: 500 | Trenutni Baseline: 80.08
# Epizoda: 486/500 | Rezultat: 500 | Trenutni Baseline: 80.10
# Epizoda: 487/500 | Rezultat: 500 | Trenutni Baseline: 80.12
# Epizoda: 488/500 | Rezultat: 500 | Trenutni Baseline: 80.14
# Epizoda: 489/500 | Rezultat: 500 | Trenutni Baseline: 80.16
# Epizoda: 490/500 | Rezultat: 500 | Trenutni Baseline: 80.18
# Epizoda: 491/500 | Rezultat: 500 | Trenutni Baseline: 80.19
# Epizoda: 492/500 | Rezultat: 500 | Trenutni Baseline: 80.21
# Epizoda: 493/500 | Rezultat: 500 | Trenutni Baseline: 80.22
# Epizoda: 494/500 | Rezultat: 500 | Trenutni Baseline: 80.23
# Epizoda: 495/500 | Rezultat: 500 | Trenutni Baseline: 80.24
# Epizoda: 496/500 | Rezultat: 500 | Trenutni Baseline: 80.25
# Epizoda: 497/500 | Rezultat: 500 | Trenutni Baseline: 80.26
# Epizoda: 498/500 | Rezultat: 500 | Trenutni Baseline: 80.27
# Epizoda: 499/500 | Rezultat: 500 | Trenutni Baseline: 80.27
# Epizoda: 500/500 | Rezultat: 500 | Trenutni Baseline: 80.28
# Težine modela su uspešno sačuvane u fajl '/content/drive/MyDrive/CartPoleREINFORCE_PyTorch/CartPoleREINFORCE_agent.pth'!

# %%
########################################################################################################################
# VIZUELIZACIJA RADA OBUČENOG AGENTA
########################################################################################################################

loaded_agent = REINFORCEAgent(state_size, action_size)
loaded_agent.model.load_state_dict(torch.load(agent_path, weights_only=True))
loaded_agent.model.eval()

print("Obučeni model je uspešno učitan sa diska.")

env_render = gym.make('CartPole-v1', render_mode='rgb_array')
state, info = env_render.reset()
state = np.reshape(state, [1, state_size])

frames = []
done = False
time_steps = 0

print("Pokrećem obučenog agenta i snimam frejmove...")

while not done:
    frames.append(env_render.render())

    state_tensor = torch.FloatTensor(state).to(device)
    with torch.no_grad():
        action_probs = loaded_agent.model(state_tensor)
        action = torch.argmax(action_probs).item()

    next_state, reward, terminated, truncated, info = env_render.step(action)
    done = terminated or truncated

    state = np.reshape(next_state, [1, state_size])
    time_steps += 1

env_render.close()

print(f"Epizoda završena nakon {time_steps} koraka. Generišem GIF animaciju...")
imageio.mimsave(gif_path, frames, duration=1000/30, loop=0)

# Prikazivanje GIF-a
display(Image(filename=gif_path))
# Out:
# Obučeni model je uspešno učitan sa diska.
# Pokrećem obučenog agenta i snimam frejmove...
# Epizoda završena nakon 500 koraka. Generišem GIF animaciju...
